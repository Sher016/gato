# %% [markdown]
# **Carga y visualización de Imágenes Médicas**
#
# Sherlyn Andrea Guzmán Graciano
#
# Miguel López Velez cc 1001014378

# %% [markdown]
# Carga y visualización de Imágenes DICOM

# %%
#importamos las librerias necesarias para manipular archivos DICOM

import pydicom
import matplotlib.pyplot as plt
#dcm_data = pydicom.dcmread(r'Data\IMG0002.dcm')
dcm_data = pydicom.dcmread(r'Data/IMG0002.dcm')
dcm_data
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 254
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.2.1125.1.58165538146238861317149318092029100
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.2.1143.107.104.103.115.3.0.9.111.124.113
# (0002, 0013) Implementation Version Name         SH: 'GDCM 3.0.9'
# (0002, 0016) Source Application Entity Title     AE: 'GDCM/ITK 5.3.0'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'MPR']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.2.1125.1.58165538146238861317149318092029100
# (0008, 0020) Study Date                          DA: '20221024'
# (0008, 0021) Series Date                         DA: '20240225'
# (0008, 0023) Content Date                        DA: '20240225'
# (0008, 0030) Study Time                          TM: '095321'
# (0008, 0031) Series Time                         TM: '175217'
# (0008, 0033) Content Time                        TM: '175217'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'Unknown manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'BRAIN MRI'
# (0008, 103e) Series Description                  LO: 'No series description'
# (0008, 1090) Manufacturer's Model Name           LO: 'Unknown model'
# (0010, 0010) Patient's Name                      PN: 'CN_0234'
# (0010, 0020) Patient ID                          LO: '1234567890'
# (0010, 0030) Patient's Birth Date                DA: '19990329'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 0050) Slice Thickness                     DS: '0.700002'
# (0018, 0088) Spacing Between Slices              DS: '1.0'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.20315836589392477186329609940459762586
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.8.498.88370686496163536554389859350453710696
# (0020, 0010) Study ID                            SH: 'SLICER10001'
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '2'
# (0020, 0032) Image Position (Patient)            DS: [93.5886, -123.801, 98.6888]
# (0020, 0037) Image Orientation (Patient)         DS: [-.0697157, .996668, -.0423385, .0029543, -.0422353, -.999103]
# (0020, 0052) Frame of Reference UID              UI: 1.2.826.0.1.3680043.8.498.50943607912586654189863052454660908373
# (0020, 1040) Position Reference Indicator        LO: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 384
# (0028, 0011) Columns                             US: 384
# (0028, 0030) Pixel Spacing                       DS: [.666666686534879, .66666668653488]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 1050) Window Center                       DS: '928.3031675549593'
# (0028, 1051) Window Width                        DS: '1856.6063351099185'
# (0028, 1054) Rescale Type                        LO: ''
# (7fe0, 0010) Pixel Data                          VR.OW: Array of 294912 elements

# %%
#Ahora, hacemos lo mismo pero para varios archivos
import os
folder = 'Data'
Lista_A = os.listdir(folder)
print("Datos cargados:",len(Lista_A))
# Out:
# Datos cargados: 243

# %%
#Teniendo la lista, leemos todos los archivos
lista_dcm_data = []

for archivo in Lista_A:
    if archivo.endswith('.dcm'):
        
        ruta_archivo = os.path.join(folder, archivo)
        lista_dcm_data.append(pydicom.dcmread(ruta_archivo))

# %%
print("Metadata leida",len(lista_dcm_data))
# Out:
# Metadata leida 243

# %%
#Ejemplo de como se ve la metadata de una imagen
lista_dcm_data[0]
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 254
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.2.1125.1.32968471229439883559269560682449196
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.2.1143.107.104.103.115.3.0.9.111.124.113
# (0002, 0013) Implementation Version Name         SH: 'GDCM 3.0.9'
# (0002, 0016) Source Application Entity Title     AE: 'GDCM/ITK 5.3.0'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'MPR']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.2.1125.1.32968471229439883559269560682449196
# (0008, 0020) Study Date                          DA: '20221024'
# (0008, 0021) Series Date                         DA: '20240225'
# (0008, 0023) Content Date                        DA: '20240225'
# (0008, 0030) Study Time                          TM: '095321'
# (0008, 0031) Series Time                         TM: '175217'
# (0008, 0033) Content Time                        TM: '175217'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'Unknown manufacturer'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'BRAIN MRI'
# (0008, 103e) Series Description                  LO: 'No series description'
# (0008, 1090) Manufacturer's Model Name           LO: 'Unknown model'
# (0010, 0010) Patient's Name                      PN: 'CN_0234'
# (0010, 0020) Patient ID                          LO: '1234567890'
# (0010, 0030) Patient's Birth Date                DA: '19990329'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 0050) Slice Thickness                     DS: '0.700002'
# (0018, 0088) Spacing Between Slices              DS: '1.0'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.20315836589392477186329609940459762586
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.8.498.88370686496163536554389859350453710696
# (0020, 0010) Study ID                            SH: 'SLICER10001'
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '238'
# (0020, 0032) Image Position (Patient)            DS: [-71.2092, -135.328, 98.6888]
# (0020, 0037) Image Orientation (Patient)         DS: [-.0697157, .996668, -.0423385, .0029543, -.0422353, -.999103]
# (0020, 0052) Frame of Reference UID              UI: 1.2.826.0.1.3680043.8.498.50943607912586654189863052454660908373
# (0020, 1040) Position Reference Indicator        LO: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 384
# (0028, 0011) Columns                             US: 384
# (0028, 0030) Pixel Spacing                       DS: [.666666686534879, .66666668653488]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 1050) Window Center                       DS: '928.3031675549593'
# (0028, 1051) Window Width                        DS: '1856.6063351099185'
# (0028, 1054) Rescale Type                        LO: ''
# (7fe0, 0010) Pixel Data                          VR.OW: Array of 294912 elements

# %%
#Vemos toda la información que podemos extraer
dcm_data. dir()
# Out:
# ['AccessionNumber',
#  'BitsAllocated',
#  'BitsStored',
#  'Columns',
#  'ContentDate',
#  'ContentTime',
#  'FrameOfReferenceUID',
#  'HighBit',
#  'ImageOrientationPatient',
#  'ImagePositionPatient',
#  'ImageType',
#  'InstanceNumber',
#  'Manufacturer',
#  'ManufacturerModelName',
#  'Modality',
#  'PatientBirthDate',
#  'PatientID',
#  'PatientName',
#  'PatientPosition',
#  'PatientSex',
#  'PhotometricInterpretation',
#  'PixelData',
#  'PixelRepresentation',
#  'PixelSpacing',
#  'PositionReferenceIndicator',
#  'ReferringPhysicianName',
#  'RescaleType',
#  'Rows',
#  'SOPClassUID',
#  'SOPInstanceUID',
#  'SamplesPerPixel',
#  'SeriesDate',
#  'SeriesDescription',
#  'SeriesInstanceUID',
#  'SeriesNumber',
#  'SeriesTime',
#  'SliceThickness',
#  'SpacingBetweenSlices',
#  'StudyDate',
#  'StudyDescription',
#  'StudyID',
#  'StudyInstanceUID',
#  'StudyTime',
#  'WindowCenter',
#  'WindowWidth']

# %%
import pandas as pd
d1=pd.DataFrame(columns=["Nombre","Modalidad","Descripción","Fecha"])
#Extraemos la información relevante de cada imagen
numero_ = 0
for archivo in lista_dcm_data:
        
        patient_name = str(archivo.PatientName)
        modality = archivo.Modality
        study_description = archivo.StudyDescription
        Date = archivo.ContentDate

        Datef = f"{Date[6:8]}/{Date[4:6]}/{Date[0:4]}"
        numero_ += 1

        #Creamos un dataframe a base de la información de cada imagen con los datos de interes
        d1.loc[numero_]=[patient_name,modality,study_description,Datef]
d1
# Out:
#       Nombre Modalidad Descripción       Fecha
# 1    CN_0234        MR   BRAIN MRI  25/02/2024
# 2    CN_0234        MR   BRAIN MRI  25/02/2024
# 3    CN_0234        MR   BRAIN MRI  25/02/2024
# 4    CN_0234        MR   BRAIN MRI  25/02/2024
# 5    CN_0234        MR   BRAIN MRI  25/02/2024
# ..       ...       ...         ...         ...
# 239  CN_0234        MR   BRAIN MRI  25/02/2024
# 240  CN_0234        MR   BRAIN MRI  25/02/2024
# 241  CN_0234        MR   BRAIN MRI  25/02/2024
# 242  CN_0234        MR   BRAIN MRI  25/02/2024
# 243  CN_0234        MR   BRAIN MRI  25/02/2024
#
# [243 rows x 4 columns]

# %% [markdown]
# Se puede observar que se toma de todos los datos ahora vamos a inspeccionar y eliminar todos los duplicados para así solo tener la información organizada de un paciente

# %%
d1=d1.drop_duplicates()
d1
# Out:
#     Nombre Modalidad Descripción       Fecha
# 1  CN_0234        MR   BRAIN MRI  25/02/2024

# %% [markdown]
# Así dejando solo la información util de solo un paciente

# %% [markdown]
# Anonimización de Datos Sensibles

# %%
from pydicom import dcmwrite
data_elements = ['PatientID','PatientBirthDate', 'PatientName','PatientSex']

# Creamos una nueva carpeta para guardar las imágenes anonimizadas
os.makedirs('anonimized_data', exist_ok=True)

# Iteramos sobre cada objeto DICOM en la lista
for i, dcm_data in enumerate(lista_dcm_data, start=1):
        
        # Anonimizamos los elementos de datos
        for element in data_elements:
            if element in dcm_data:
                dcm_data[element].value = 'anonimo'

        # Guardamos la imagen anonimizada en una nueva carpeta
        new_filename = f'anonimized_data/00_{i}_anonimo.dcm'
        dcmwrite(new_filename, dcm_data)
        print(f'Imagen anonimizada {i} guardada como {new_filename}')
# Out:
# /home/astolfo/anaconda3/lib/python3.11/site-packages/pydicom/valuerep.py:443: UserWarning: Invalid value for VR DA: 'anonimo'.
#   warnings.warn(msg)
# /home/astolfo/anaconda3/lib/python3.11/site-packages/pydicom/valuerep.py:443: UserWarning: Invalid value for VR CS: 'anonimo'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   
# Imagen anonimizada 126 guardada como anonimized_data/00_126_anonimo.dcm
# Imagen anonimizada 127 guardada como anonimized_data/00_127_anonimo.dcm
# Imagen anonimizada 128 guardada como anonimized_data/00_128_anonimo.dcm
# Imagen anonimizada 129 guardada como anonimized_data/00_129_anonimo.dcm
# Imagen anonimizada 130 guardada como anonimized_data/00_130_anonimo.dcm
# Imagen anonimizada 131 guardada como anonimized_data/00_131_anonimo.dcm
# Imagen anonimizada 132 guardada como anonimized_data/00_132_anonimo.dcm
# Imagen anonimizada 133 guardada como anonimized_data/00_133_anonimo.dcm
# Imagen anonimizada 134 guardada como anonimized_data/00_134_anonimo.dcm
# Imagen anonimizada 135 guardada como anonimized_data/00_135_anonimo.dcm
# Imagen anonimizada 136 guardada como anonimized_data/00_136_anonimo.dcm
# Imagen anonimizada 137 guardada como anonimized_data/00_137_anonimo.dcm
# Imagen anonimizada 138 guardada como anonimized_data/00_138_anonimo.dcm
# Imagen anonimizada 139 guardada como anonimized_data/00_139_anonimo.dcm
# Imagen anonimizada 140 guardada como anonimized_data/00_140_anonimo.dcm
# Imagen anonimizada 141 guardada como anonimized_data/00_141_anonimo.dcm
# Imagen anonimizada 142 guardada como anonimized_data/00_142_anonimo.dcm
# Imagen anonimizada 143 guardada como anonimized_data/00_143_anonimo.dcm
# Imagen anonimizada 144 guardada como anonimized_data/00_144_anonimo.dcm
# Imagen anonimizada 145 guardada como anonimized_data/00_145_anonimo.dcm
# Imagen anonimizada 146 guardada como anonimized_data/00_146_anonimo.dcm
# Imagen anonimizada 147 guardada como anonimized_data/00_147_anonimo.dcm
# Imagen anonimizada 148 guardada como anonimized_data/00_148_anonimo.dcm
# Imagen anonimizada 149 guardada como anonimized_data/00_149_anonimo.dcm
# Imagen anonimizada 150 guardada como anonimized_data/00_150_anonimo.dcm
# Imagen anonimizada 151 guardada como anonimized_data/00_151_anonimo.dcm
# Imagen anonimizada 152 guardada como anonimized_data/00_152_anonimo.dcm
# Imagen anonimizada 153 guardada como anonimized_data/00_153_anonimo.dcm
# Imagen anonimizada 154 guardada como anonimized_data/00_154_anonimo.dcm
# Imagen anonimizada 155 guardada como anonimized_data/00_155_anonimo.dcm
# Imagen anonimizada 156 guardada como anonimized_data/00_156_anonimo.dcm
# Imagen anonimizada 157 guardada como anonimized_data/00_157_anonimo.dcm
# Imagen anonimizada 158 guardada como anonimized_data/00_158_anonimo.dcm
# Imagen anonimizada 159 guardada como anonimized_data/00_159_anonimo.dcm
# Imagen anonimizada 160 guardada como anonimized_data/00_160_anonimo.dcm
# Imagen anonimizada 161 guardada como anonimized_data/00_161_anonimo.dcm
# Imagen anonimizada 162 guardada como anonimized_data/00_162_anonimo.dcm
# Imagen anonimizada 163 guardada como anonimized_data/00_163_anonimo.dcm
# Imagen anonimizada 164 guardada como anonimized_data/00_164_anonimo.dcm
# Imagen anonimizada 165 guardada como anonimized_data/00_165_anonimo.dcm
# Imagen anonimizada 166 guardada como anonimized_data/00_166_anonimo.dcm
# Imagen anonimizada 167 guardada como anonimized_data/00_167_anonimo.dcm
# Imagen anonimizada 168 guardada como anonimized_data/00_168_anonimo.dcm
# Imagen anonimizada 169 guardada como anonimized_data/00_169_anonimo.dcm
# Imagen anonimizada 170 guardada como anonimized_data/00_170_anonimo.dcm
# Imagen anonimizada 171 guardada como anonimized_data/00_171_anonimo.dcm
# Imagen anonimizada 172 guardada como anonimized_data/00_172_anonimo.dcm
# Imagen anonimizada 173 guardada como anonimized_data/00_173_anonimo.dcm
# Imagen anonimizada 174 guardada como anonimized_data/00_174_anonimo.dcm
# Imagen anonimizada 175 guardada como anonimized_data/00_175_anonimo.dcm
# Imagen anonimizada 176 guardada como anonimized_data/00_176_anonimo.dcm
# Imagen anonimizada 177 guardada como anonimized_data/00_177_anonimo.dcm
# Imagen anonimizada 178 guardada como anonimized_data/00_178_anonimo.dcm
# Imagen anonimizada 179 guardada como anonimized_data/00_179_anonimo.dcm
# Imagen anonimizada 180 guardada como anonimized_data/00_180_anonimo.dcm
# Imagen anonimizada 181 guardada como anonimized_data/00_181_anonimo.dcm
# Imagen anonimizada 182 guardada como anonimized_data/00_182_anonimo.dcm
# Imagen anonimizada 183 guardada como anonimized_data/00_183_anonimo.dcm
# Imagen anonimizada 184 guardada como anonimized_data/00_184_anonimo.dcm
# Imagen anonimizada 185 guardada como anonimized_data/00_185_anonimo.dcm
# Imagen anonimizada 186 guardada como anonimized_data/00_186_anonimo.dcm
# Imagen anonimizada 187 guardada como anonimized_data/00_187_anonimo.dcm
# Imagen anonimizada 188 guardada como anonimized_data/00_188_anonimo.dcm
# Imagen anonimizada 189 guardada como anonimized_data/00_189_anonimo.dcm
# Imagen anonimizada 190 guardada como anonimized_data/00_190_anonimo.dcm
# Imagen anonimizada 191 guardada como anonimized_data/00_191_anonimo.dcm
# Imagen anonimizada 192 guardada como anonimized_data/00_192_anonimo.dcm
# Imagen anonimizada 193 guardada como anonimized_data/00_193_anonimo.dcm
# Imagen anonimizada 194 guardada como anonimized_data/00_194_anonimo.dcm
# Imagen anonimizada 195 guardada como anonimized_data/00_195_anonimo.dcm
# Imagen anonimizada 196 guardada como anonimized_data/00_196_anonimo.dcm
# Imagen anonimizada 197 guardada como anonimized_data/00_197_anonimo.dcm
# Imagen anonimizada 198 guardada como anonimized_data/00_198_anonimo.dcm
# Imagen anonimizada 199 guardada como anonimized_data/00_199_anonimo.dcm
# Imagen anonimizada 200 guardada como anonimized_data/00_200_anonimo.dcm
# Imagen anonimizada 201 guardada como anonimized_data/00_201_anonimo.dcm
# Imagen anonimizada 202 guardada como anonimized_data/00_202_anonimo.dcm
# Imagen anonimizada 203 guardada como anonimized_data/00_203_anonimo.dcm
# Imagen anonimizada 204 guardada como anonimized_data/00_204_anonimo.dcm
# Imagen anonimizada 205 guardada como anonimized_data/00_205_anonimo.dcm
# Imagen anonimizada 206 guardada como anonimized_data/00_206_anonimo.dcm
# Imagen anonimizada 207 guardada como anonimized_data/00_207_anonimo.dcm
# Imagen anonimizada 208 guardada como anonimized_data/00_208_anonimo.dcm
# Imagen anonimizada 209 guardada como anonimized_data/00_209_anonimo.dcm
# Imagen anonimizada 210 guardada como anonimized_data/00_210_anonimo.dcm
# Imagen anonimizada 211 guardada como anonimized_data/00_211_anonimo.dcm
# Imagen anonimizada 212 guardada como anonimized_data/00_212_anonimo.dcm
# Imagen anonimizada 213 guardada como anonimized_data/00_213_anonimo.dcm
# Imagen anonimizada 214 guardada como anonimized_data/00_214_anonimo.dcm
# Imagen anonimizada 215 guardada como anonimized_data/00_215_anonimo.dcm
# Imagen anonimizada 216 guardada como anonimized_data/00_216_anonimo.dcm
# Imagen anonimizada 217 guardada como anonimized_data/00_217_anonimo.dcm
# Imagen anonimizada 218 guardada como anonimized_data/00_218_anonimo.dcm
# Imagen anonimizada 219 guardada como anonimized_data/00_219_anonimo.dcm
# Imagen anonimizada 220 guardada como anonimized_data/00_220_anonimo.dcm
# Imagen anonimizada 221 guardada como anonimized_data/00_221_anonimo.dcm
# Imagen anonimizada 222 guardada como anonimized_data/00_222_anonimo.dcm
# Imagen anonimizada 223 guardada como anonimized_data/00_223_anonimo.dcm
# Imagen anonimizada 224 guardada como anonimized_data/00_224_anonimo.dcm
# Imagen anonimizada 225 guardada como anonimized_data/00_225_anonimo.dcm
# Imagen anonimizada 226 guardada como anonimized_data/00_226_anonimo.dcm
# Imagen anonimizada 227 guardada como anonimized_data/00_227_anonimo.dcm
# Imagen anonimizada 228 guardada como anonimized_data/00_228_anonimo.dcm
# Imagen anonimizada 229 guardada como anonimized_data/00_229_anonimo.dcm
# Imagen anonimizada 230 guardada como anonimized_data/00_230_anonimo.dcm
# Imagen anonimizada 231 guardada como anonimized_data/00_231_anonimo.dcm
# Imagen anonimizada 232 guardada como anonimized_data/00_232_anonimo.dcm
# Imagen anonimizada 233 guardada como anonimized_data/00_233_anonimo.dcm
# Imagen anonimizada 234 guardada como anonimized_data/00_234_anonimo.dcm
# Imagen anonimizada 235 guardada como anonimized_data/00_235_anonimo.dcm
# Imagen anonimizada 236 guardada como anonimized_data/00_236_anonimo.dcm
# Imagen anonimizada 237 guardada como anonimized_data/00_237_anonimo.dcm
# Imagen anonimizada 238 guardada como anonimized_data/00_238_anonimo.dcm
# Imagen anonimizada 239 guardada como anonimized_data/00_239_anonimo.dcm
# Imagen anonimizada 240 guardada como anonimized_data/00_240_anonimo.dcm
# Imagen anonimizada 241 guardada como anonimized_data/00_241_anonimo.dcm
# Imagen anonimizada 242 guardada como anonimized_data/00_242_anonimo.dcm
# Imagen anonimizada 243 guardada como anonimized_data/00_243_anonimo.dcm

# %%
#Ahora revisamos una nueva imagen para ver si los elementos escogidos fueron anonimizados

dcm_data_anonimized = pydicom.dcmread(r'anonimized_data\/00_1_anonimo.dcm')
dcm_data_anonimized.PatientName
# Out:
# 'anonimo'
